# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/knoldus/anaconda3/lib/python3.8/site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in /home/knoldus/anaconda3/lib/python3.8/site-packages (from opencv-python) (1.19.2)
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/knoldus/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# ### Load Image

# %%
 def read_file(filename):
        img = cv2.imread(filename)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.show()
        return img

# %%
filename = "image.jpg"
img = read_file(filename)

org_image=np.copy(img)

# %% [markdown]
# ### Create Edge Mask

# %%
def edge_mask(img, line_size, blur_value):
    """
    input: Input Image
    Output: Edges of Images
    
    """
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray_blur = cv2.medianBlur(gray, blur_value)
    
    edges = cv2.adaptiveThreshold(gray_blur, 255,
                                  cv2.ADAPTIVE_THRESH_MEAN_C,
                                  cv2.THRESH_BINARY,
                                  line_size, blur_value)
    return edges

# %%
line_size,blur_value = 9,9

edges = edge_mask(img, line_size, blur_value)

plt.imshow(edges, cmap="gray")
plt.show()

# %% [markdown]
# ### Reduce the color Palette

# %%
def color_quantization(img, k):
    # Transform the image
    data = np.float32(img).reshape((-1,3))
    
    #Determine Criteria
    criteria = (cv2.TERM_CRITERIA_EPS+ cv2.TERM_CRITERIA_MAX_ITER, 20, 0.001)
    
    ##Implementing K-Means
    ret, label, center = cv2.kmeans(data, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
    center = np.uint8(center)
    result=center[label.flatten()]
    result = result.reshape(img.shape)
    
    return result

# %%
img_quantiz = color_quantization(img, k=7)

plt.imshow(img_quantiz)
plt.show()

# %%
# Reduce the noise

blurred = cv2.bilateralFilter(img_quantiz, d=4, sigmaColor=200, sigmaSpace=200)

plt.imshow(blurred)
plt.show()

# %% [markdown]
# ### Combine Edge Mask with quantiz img

# %%
def cartoon():
    c = cv2.bitwise_and(blurred, blurred,mask= edges)
    
    plt.figure(figsize=(15, 15))
    plt.imshow(c)
    plt.title("Cartoon Image")
    plt.show()
    
    plt.imshow(org_image)
    plt.title("Original Image")
    plt.show()

# %%
cartoon()
